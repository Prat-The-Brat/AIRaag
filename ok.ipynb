# %%
import os
import json
import numpy as np
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf

duration = librosa.get_duration(filename='Data/genres_original/jazz/jazz.00054.wav')
print(f"Duration of the audio file: {duration} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 duration = librosa.get_duration(filename='Data/genres_original/jazz/jazz.00054.wav')
#       2 print(f"Duration of the audio file: {duration} seconds")
#
# NameError: name 'librosa' is not defined
